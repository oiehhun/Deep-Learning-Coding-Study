# %% [markdown]
# # 모듈 호출

# %%
# 파이토치 불러오기
import torch
import torch.nn as nn

# 데이터셋 불러오기
from torchvision.transforms import transforms
from torchvision.datasets import CIFAR10

# 데이터 로더
from torch.utils.data.dataloader import DataLoader

# 최적화 알고리즘
from torch.optim import optimizer

# numpy
import numpy as np

# matplotlib
import matplotlib.pyplot as plt

# %%
# 시드 고정
torch.manual_seed(1)
torch.cuda.manual_seed(1)
torch.cuda.manual_seed_all(1)
np.random.seed(1)

# %%
transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomHorizontalFlip(0.5),
    transforms.ToTensor()
])

# %% [markdown]
# # 데이터 호출

# %%
# 데이터 호출(CIFAR 10)
path = '/home/xogns5037/딥러닝코딩스터디/data/CIFAR10'


train_data = CIFAR10(
    root = path,
    train=True,
    download=True,
    transform=transform
)

test_data = CIFAR10(
    root = path,
    train=False,
    download=True,
    transform=transform
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # 이미지 정규화

# %%
# 이미지 정규화
imgs = np.array([img.numpy() for img, _ in train_data])
print(f'img shape : {imgs.shape}')
# Out:
# img shape : (50000, 3, 224, 224)

# %%
classes = train_data.classes
classes
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
# frog로 보임
plt.imshow(imgs[0].transpose(1,2,0)) # transpose : 차원을 바꿔줌 (3,32,32) -> (32,32,3)

# %%
# 반복문을 통해 grid로 보기
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(imgs[i].transpose(1,2,0))
    plt.axis('off')

# %% [markdown]
# # 데이터 로더

# %%
batch_size = 256
num_workers = 4

train_dataloader = DataLoader(
    dataset=train_data,
    batch_size=batch_size,
    shuffle=True,
    num_workers=num_workers,
)

test_dataloader = DataLoader(
    dataset=test_data,
    batch_size=batch_size,
    shuffle=False,
    num_workers=num_workers,
)

# %%
print(train_dataloader.dataset)
print(f'Total {len(train_dataloader)} images in 1 batch')
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: /home/xogns5037/딥러닝코딩스터디/data/CIFAR10
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=warn)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#            )
# Total 196 images in 1 batch

# %% [markdown]
# # 모델 생성

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 인셉션 모듈 만들기
# input을 받으면 각각 1*1, 1*1 -> 3*3, 1*1 -> 5*5, 3*3 -> 1*1 을 거친 4개의 값을 concatenation을 해주면 됨

class inception_module(nn.Module):
    def __init__(self, in_channels, ch1x1, ch3x3_in, ch3x3_out, ch5x5_in, ch5x5_out, pool):
        super(inception_module, self).__init__()

        # 1*1 conv
        self.conv1x1 = nn.Sequential(
            nn.Conv2d(in_channels=in_channels, out_channels=ch1x1, kernel_size=1), # 1x1 conv
            nn.ReLU(inplace=True)
        )

        # 1*1 conv -> 3*3 conv
        self.conv3x3 = nn.Sequential(
            nn.Conv2d(in_channels=in_channels, out_channels=ch3x3_in, kernel_size=1), # 1*1 conv
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=ch3x3_in, out_channels=ch3x3_out, kernel_size=3, padding=1), # 3x3 conv
            nn.ReLU(inplace=True),
        )

        # 1*1 conv -> 5*5 conv
        self.conv5x5 = nn.Sequential(
            nn.Conv2d(in_channels=in_channels, out_channels=ch5x5_in, kernel_size=1), # 1*1 conv
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=ch5x5_in, out_channels=ch5x5_out, kernel_size=5, stride=1, padding=2), # 5x5 conv
            nn.ReLU(inplace=True),
        )

        # 3*3 max pool -> 1*1 conv
        self.pool = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1), # 3x3 maxpool
            nn.Conv2d(in_channels=in_channels, out_channels=pool, kernel_size=1), # 1x1 conv
            nn.ReLU(inplace=True)
        )

    def forward(self, x : torch.Tensor) -> torch.Tensor: # 속성 명시
        # 각 모듈별 데이터 input
        out1 = self.conv1x1(x)
        out2 = self.conv3x3(x)
        out3 = self.conv5x5(x)
        out4 = self.pool(x)

        # 각 모듈별 결과 concat
        output = torch.cat([out1, out2, out3, out4], 1)
        return output

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 학습에 사용되는 auxiliary classifier
class Aux(nn.Module):
    def __init__(self, in_channels, num_classes) -> None:
        super().__init__()

        # 4a : average pooling(5*5 filter, stride 3, result = 4*4*512)
        # 4d : average pooling(5*5 filter, stride 3, result = 4*4*528)
        self.avgpool =  nn.AvgPool2d(kernel_size=5, stride=3, padding=1)

        # 1*1 conv with 128 filters, + relu
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels=in_channels, out_channels=128, kernel_size=1, stride=1, padding=0),
            nn.ReLU(inplace=True)
        )

        # fc layer with 1024 units + relu
        # dropout layer with 70% ratio
        self.fc = nn.Sequential(
                nn.Linear(4*4*128, 1024),
                nn.ReLU(inplace=True),
                nn.Dropout(0.7),
                nn.Linear(1024, num_classes)
        )

    def forward(self, x):
        x = self.avgpool(x)
        x = self.conv(x)
        x = torch.flatten(x, 1) # flatten
        x = self.fc(x)
        return x

# %%
# GoogLeNet 구현
class GoogLeNet(nn.Module):
    def __init__(self, training, num_classes)-> None:
        super().__init__()

        self.training = True

        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=7, stride=2, padding=3),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
            nn.LocalResponseNorm(2)
        )

        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=64, out_channels=192, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
            nn.LocalResponseNorm(2)
        )

        # inception 3
        self.inception_3a = inception_module(in_channels=192, ch1x1=64, ch3x3_in=96, ch3x3_out=128, ch5x5_in=16, ch5x5_out=32, pool=32)
        self.inception_3b = inception_module(256, 128, 128, 192, 32, 96, 64)
        self.maxpool_3 = nn.MaxPool2d(3,2,1)

        # inception 4
        self.inception_4a = inception_module(480, 192, 96, 208, 16, 48, 64)
        self.aux1 = Aux(512, num_classes) # 보조 학습기 1

        self.inception_4b = inception_module(512, 160, 112, 224, 24, 64, 64)
        self.inception_4c = inception_module(512, 128, 128, 256, 24, 64, 64)
        self.inception_4d = inception_module(512, 112, 144, 288, 32, 64, 64)
        self.aux2 = Aux(528, num_classes) # 보조 학습기 2

        self.inception_4e = inception_module(528, 256, 160, 320, 32, 128, 128)
        self.maxpool_4 = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)

        # inception 5
        self.inception_5a = inception_module(832, 256, 160, 320, 32, 128, 128)
        self.inception_5b = inception_module(832, 384, 192, 384, 48, 128, 128)

        # fully connected
        self.avg = nn.AvgPool2d(kernel_size=7, stride=1) # adaptive avgpool로 대체 가능
        self.dropout = nn.Dropout2d(0.4) # 40%
        self.fc = nn.Linear(1024, num_classes)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.inception_3a(x)
        x = self.inception_3b(x)
        x = self.maxpool_3(x)

        x = self.inception_4a(x)
        if self.training :
            aux_out1 = self.aux1(x)

        x = self.inception_4b(x)
        x = self.inception_4c(x)
        x = self.inception_4d(x)
        if self.training:
            aux_out2 = self.aux2(x)

        x = self.inception_4e(x)
        x = self.maxpool_4(x)

        x = self.inception_5a(x)
        x = self.inception_5b(x)

        x = self.avg(x)
        x = self.dropout(x)

        x = torch.flatten(x, 1)
        x = self.fc(x)

        if self.training:
            return [aux_out1, aux_out2, x]
        else :
            return x

# %%
model = GoogLeNet(training=True, num_classes=10)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using {device} device')
model.to(device)
# Out:
# Using cuda device
# GoogLeNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): LocalResponseNorm(2, alpha=0.0001, beta=0.75, k=1.0)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (5): LocalResponseNorm(2, alpha=0.0001, beta=0.75, k=1.0)
#   )
#   (inception_3a): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (inception_3b): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (maxpool_3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (inception_4a): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (aux1): Aux(
#     (avgpool): AvgPool2d(kernel_size=5, stride=3, padding=1)
#     (conv): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=2048, out_features=1024, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.7, inplace=False)
#       (3): Linear(in_features=1024, out_features=10, bias=True)
#     )
#   )
#   (inception_4b): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (inception_4c): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (inception_4d): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (aux2): Aux(
#     (avgpool): AvgPool2d(kernel_size=5, stride=3, padding=1)
#     (conv): Sequential(
#       (0): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=2048, out_features=1024, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.7, inplace=False)
#       (3): Linear(in_features=1024, out_features=10, bias=True)
#     )
#   )
#   (inception_4e): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (maxpool_4): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (inception_5a): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (inception_5b): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (avg): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (dropout): Dropout2d(p=0.4, inplace=False)
#   (fc): Linear(in_features=1024, out_features=10, bias=True)
# )

# %% [markdown]
# # 모델 확인

# %%
from torchsummary import summary
model = GoogLeNet(training=True, num_classes=10).cuda()
summary(model, input_size=(3,224,224), device='cuda')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,472
#               ReLU-2         [-1, 64, 112, 112]               0
#          MaxPool2d-3           [-1, 64, 56, 56]               0
#  LocalResponseNorm-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,160
#               ReLU-6           [-1, 64, 56, 56]               0
#             Conv2d-7          [-1, 192, 56, 56]         110,784
#               ReLU-8          [-1, 192, 56, 56]               0
#          MaxPool2d-9          [-1, 192, 28, 28]               0
# LocalResponseNorm-10          [-1, 192, 28, 28]               0
#            Conv2d-11           [-1, 64, 28, 28]          12,352
#              ReLU-12           [-1, 64, 28, 28]               0
#            Conv2d-13           [-1, 96, 28, 28]          18,528
#              ReLU-14           [-1, 96, 28, 28]               0
#            Conv2d-15          [-1, 128, 28, 28]         110,720
#              ReLU-16          [-1, 128, 28, 28]               0
#            Conv2d-17           [-1, 16, 28, 28]           3,088
#              ReLU-18           [-1, 16, 28, 28]               0
#            Conv2d-19           [-1, 32, 28, 28]          12,832
#              ReLU-20           [-1, 32, 28, 28]               0
#         MaxPool2d-21          [-1, 192, 28, 28]               0
#            Conv2d-22           [-1, 32, 28, 28]           6,176
#              ReLU-23           [-1, 32, 28, 28]               0
#  inception_module-24          [-1, 256, 28, 28]               0
#            Conv2d-25          [-1, 128, 28, 28]          32,896
#              ReLU-26          [-1, 128, 28, 28]               0
#            Conv2d-27          [-1, 128, 28, 28]          32,896
#              ReLU-28          [-1, 128, 28, 28]               0
#            Conv2d-29          [-1, 192, 28, 28]         221,376
#              ReLU-30          [-1, 192, 28, 28]               0
#            Conv2d-31           [-1, 32, 28, 28]           8,224
#              ReLU-32           [-1, 32, 28, 28]               0
#            Conv2d-33           [-1, 96, 28, 28]          76,896
#              ReLU-34           [-1, 96, 28, 28]               0
#         MaxPool2d-35          [-1, 256, 28, 28]               0
#            Conv2d-36           [-1, 64, 28, 28]          16,448
#              ReLU-37           [-1, 64, 28, 28]               0
#  inception_module-38          [-1, 480, 28, 28]               0
#         MaxPool2d-39          [-1, 480, 14, 14]               0
#            Conv2d-40          [-1, 192, 14, 14]          92,352
#              ReLU-41          [-1, 192, 14, 14]               0
#            Conv2d-42           [-1, 96, 14, 14]          46,176
#              ReLU-43           [-1, 96, 14, 14]               0
#            Conv2d-44          [-1, 208, 14, 14]         179,920
#              ReLU-45          [-1, 208, 14, 14]               0
#            Conv2d-46           [-1, 16, 14, 14]           7,696
#              ReLU-47           [-1, 16, 14, 14]               0
#            Conv2d-48           [-1, 48, 14, 14]          19,248
#              ReLU-49           [-1, 48, 14, 14]               0
#         MaxPool2d-50          [-1, 480, 14, 14]               0
#            Conv2d-51           [-1, 64, 14, 14]          30,784
#              ReLU-52           [-1, 64, 14, 14]               0
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 160, 14, 14]          84,640
#             ReLU-115          [-1, 160, 14, 14]               0
#           Conv2d-116          [-1, 320, 14, 14]         461,120
#             ReLU-117          [-1, 320, 14, 14]               0
#           Conv2d-118           [-1, 32, 14, 14]          16,928
#             ReLU-119           [-1, 32, 14, 14]               0
#           Conv2d-120          [-1, 128, 14, 14]         102,528
#             ReLU-121          [-1, 128, 14, 14]               0
#        MaxPool2d-122          [-1, 528, 14, 14]               0
#           Conv2d-123          [-1, 128, 14, 14]          67,712
#             ReLU-124          [-1, 128, 14, 14]               0
# inception_module-125          [-1, 832, 14, 14]               0
#        MaxPool2d-126            [-1, 832, 7, 7]               0
#           Conv2d-127            [-1, 256, 7, 7]         213,248
#             ReLU-128            [-1, 256, 7, 7]               0
#           Conv2d-129            [-1, 160, 7, 7]         133,280
#             ReLU-130            [-1, 160, 7, 7]               0
#           Conv2d-131            [-1, 320, 7, 7]         461,120
#             ReLU-132            [-1, 320, 7, 7]               0
#           Conv2d-133             [-1, 32, 7, 7]          26,656
#             ReLU-134             [-1, 32, 7, 7]               0
#           Conv2d-135            [-1, 128, 7, 7]         102,528
#             ReLU-136            [-1, 128, 7, 7]               0
#        MaxPool2d-137            [-1, 832, 7, 7]               0
#           Conv2d-138            [-1, 128, 7, 7]         106,624
#             ReLU-139            [-1, 128, 7, 7]               0
# inception_module-140            [-1, 832, 7, 7]               0
#           Conv2d-141            [-1, 384, 7, 7]         319,872
#             ReLU-142            [-1, 384, 7, 7]               0
#           Conv2d-143            [-1, 192, 7, 7]         159,936
#             ReLU-144            [-1, 192, 7, 7]               0
#           Conv2d-145            [-1, 384, 7, 7]         663,936
#             ReLU-146            [-1, 384, 7, 7]               0
#           Conv2d-147             [-1, 48, 7, 7]          39,984
#             ReLU-148             [-1, 48, 7, 7]               0
#           Conv2d-149            [-1, 128, 7, 7]         153,728
#             ReLU-150            [-1, 128, 7, 7]               0
#        MaxPool2d-151            [-1, 832, 7, 7]               0
#           Conv2d-152            [-1, 128, 7, 7]         106,624
#             ReLU-153            [-1, 128, 7, 7]               0
# inception_module-154           [-1, 1024, 7, 7]               0
#        AvgPool2d-155           [-1, 1024, 1, 1]               0
#        Dropout2d-156           [-1, 1024, 1, 1]               0
#           Linear-157                   [-1, 10]          10,250
# ================================================================
# Total params: 10,334,030
# Trainable params: 10,334,030
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 72.40
# Params size (MB): 39.42
# Estimated Total Size (MB): 112.40
# ----------------------------------------------------------------

# %% [markdown]
# # 학습 loss, 최적화 알고리즘 확인

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

criterion.to(device=device)
model.to(device=device)
# Out:
# GoogLeNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (3): LocalResponseNorm(2, alpha=0.0001, beta=0.75, k=1.0)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (5): LocalResponseNorm(2, alpha=0.0001, beta=0.75, k=1.0)
#   )
#   (inception_3a): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (inception_3b): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (maxpool_3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (inception_4a): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (aux1): Aux(
#     (avgpool): AvgPool2d(kernel_size=5, stride=3, padding=1)
#     (conv): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=2048, out_features=1024, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.7, inplace=False)
#       (3): Linear(in_features=1024, out_features=10, bias=True)
#     )
#   )
#   (inception_4b): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (inception_4c): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (inception_4d): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (aux2): Aux(
#     (avgpool): AvgPool2d(kernel_size=5, stride=3, padding=1)
#     (conv): Sequential(
#       (0): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=2048, out_features=1024, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.7, inplace=False)
#       (3): Linear(in_features=1024, out_features=10, bias=True)
#     )
#   )
#   (inception_4e): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (maxpool_4): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (inception_5a): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (inception_5b): inception_module(
#     (conv1x1): Sequential(
#       (0): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (conv3x3): Sequential(
#       (0): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#     (conv5x5): Sequential(
#       (0): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (3): ReLU(inplace=True)
#     )
#     (pool): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#     )
#   )
#   (avg): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (dropout): Dropout2d(p=0.4, inplace=False)
#   (fc): Linear(in_features=1024, out_features=10, bias=True)
# )

# %% [markdown]
# # 학습
# 보조 학습기가 있기 때문에 loss를 추후 합산해야함(각 보조 학습기의 가중치는 0.3)

# %%
# 학습
num_epochs = 100 # 에폭 설정

loss_arr = []
for epoch in range(num_epochs):
    running_loss = 0.0

    for i, data in enumerate(train_dataloader):
        images, labels = data
        images, labels = images.to(device), labels.to(device)

        #Forward pass
        output_1, output_2, output_3 = model(images) # 모델 예측 시행

        # 예측에 따른 손실 계산 및 출력
        loss_1 = criterion(output_1, labels)  # 보조분류기 1
        loss_2 = criterion(output_2, labels)  # 보조분류기 2
        loss_3 = criterion(output_3, labels)  # 최종 결과물

        loss = loss_1 * 0.3 + loss_2 * 0.3 + loss_3

        # backward pass
        optimizer.zero_grad() # 가중치 변화를 0으로 만들고
        loss.backward() # 역전파를 수행하고
        optimizer.step() # 가중치를 갱신

        running_loss += loss.item()
        loss_arr.append(loss.item())
        # 100번에 한번씩 loss 출력
        if i % 19 == 18:
            print(f'Training epoch : {epoch+1}, [{i * len(images)} / {len(train_dataloader.dataset)}] ({100 * i / len(train_dataloader):0.0f}%), Loss : {running_loss/19:0.6f}')
            running_loss = 0.0

print('학습종료!')
# Out:
# Training epoch : 1, [4608 / 50000] (9%), Loss : 3.684506
# Training epoch : 1, [9472 / 50000] (19%), Loss : 3.684861
# Training epoch : 1, [14336 / 50000] (29%), Loss : 3.682943
# Training epoch : 1, [19200 / 50000] (38%), Loss : 3.664881
# Training epoch : 1, [24064 / 50000] (48%), Loss : 3.593265
# Training epoch : 1, [28928 / 50000] (58%), Loss : 3.402325
# Training epoch : 1, [33792 / 50000] (67%), Loss : 3.322029
# Training epoch : 1, [38656 / 50000] (77%), Loss : 3.286353
# Training epoch : 1, [43520 / 50000] (87%), Loss : 3.252620
# Training epoch : 1, [48384 / 50000] (96%), Loss : 3.220800
# Training epoch : 2, [4608 / 50000] (9%), Loss : 3.200518
# Training epoch : 2, [9472 / 50000] (19%), Loss : 3.143412
# Training epoch : 2, [14336 / 50000] (29%), Loss : 3.130636
# Training epoch : 2, [19200 / 50000] (38%), Loss : 3.116177
# Training epoch : 2, [24064 / 50000] (48%), Loss : 3.059557
# Training epoch : 2, [28928 / 50000] (58%), Loss : 3.064427
# Training epoch : 2, [33792 / 50000] (67%), Loss : 3.048834
# Training epoch : 2, [38656 / 50000] (77%), Loss : 3.022069
# Training epoch : 2, [43520 / 50000] (87%), Loss : 2.982212
# Training epoch : 2, [48384 / 50000] (96%), Loss : 2.984506
# Training epoch : 3, [4608 / 50000] (9%), Loss : 2.961377
# Training epoch : 3, [9472 / 50000] (19%), Loss : 2.977420
# Training epoch : 3, [14336 / 50000] (29%), Loss : 2.908211
# Training epoch : 3, [19200 / 50000] (38%), Loss : 2.901969
# Training epoch : 3, [24064 / 50000] (48%), Loss : 2.917879
# Training epoch : 3, [28928 / 50000] (58%), Loss : 2.879481
# Training epoch : 3, [33792 / 50000] (67%), Loss : 2.861578
# Training epoch : 13, [14336 / 50000] (29%), Loss : 2.132034
# Training epoch : 13, [19200 / 50000] (38%), Loss : 2.129854
# Training epoch : 13, [24064 / 50000] (48%), Loss : 2.130928
# Training epoch : 13, [28928 / 50000] (58%), Loss : 2.131440
# Training epoch : 13, [33792 / 50000] (67%), Loss : 2.133375
# Training epoch : 13, [38656 / 50000] (77%), Loss : 2.182807
# Training epoch : 13, [43520 / 50000] (87%), Loss : 2.179475
# Training epoch : 13, [48384 / 50000] (96%), Loss : 2.104697
# Training epoch : 14, [4608 / 50000] (9%), Loss : 2.127777
# Training epoch : 14, [9472 / 50000] (19%), Loss : 2.081860
# Training epoch : 14, [14336 / 50000] (29%), Loss : 2.077214
# Training epoch : 14, [19200 / 50000] (38%), Loss : 2.117047
# Training epoch : 14, [24064 / 50000] (48%), Loss : 2.108033
# Training epoch : 14, [28928 / 50000] (58%), Loss : 2.058453
# Training epoch : 14, [33792 / 50000] (67%), Loss : 2.107128
# Training epoch : 14, [38656 / 50000] (77%), Loss : 2.055413
# Training epoch : 14, [43520 / 50000] (87%), Loss : 2.069624
# Training epoch : 14, [48384 / 50000] (96%), Loss : 2.115508
# Training epoch : 15, [4608 / 50000] (9%), Loss : 2.066858
# Training epoch : 15, [9472 / 50000] (19%), Loss : 2.072442
# Training epoch : 15, [14336 / 50000] (29%), Loss : 2.099441
# Training epoch : 15, [19200 / 50000] (38%), Loss : 2.065530
# Training epoch : 15, [24064 / 50000] (48%), Loss : 2.024352
# Training epoch : 15, [28928 / 50000] (58%), Loss : 2.035471
# Training epoch : 15, [33792 / 50000] (67%), Loss : 2.033643
# Training epoch : 15, [38656 / 50000] (77%), Loss : 2.043311
# Training epoch : 15, [43520 / 50000] (87%), Loss : 2.076229
# Training epoch : 15, [48384 / 50000] (96%), Loss : 2.016147
# Training epoch : 16, [4608 / 50000] (9%), Loss : 2.000783
# Training epoch : 16, [9472 / 50000] (19%), Loss : 2.012245
# Training epoch : 16, [14336 / 50000] (29%), Loss : 2.032536
# Training epoch : 16, [19200 / 50000] (38%), Loss : 1.998282
# Training epoch : 16, [24064 / 50000] (48%), Loss : 2.061273
# Training epoch : 16, [28928 / 50000] (58%), Loss : 2.016371
# Training epoch : 16, [33792 / 50000] (67%), Loss : 2.047620
# Training epoch : 16, [38656 / 50000] (77%), Loss : 2.051855
# Training epoch : 16, [43520 / 50000] (87%), Loss : 2.040171
# Training epoch : 16, [48384 / 50000] (96%), Loss : 2.009262
# Training epoch : 17, [4608 / 50000] (9%), Loss : 1.978550
# Training epoch : 17, [9472 / 50000] (19%), Loss : 1.996403
# Training epoch : 17, [14336 / 50000] (29%), Loss : 1.959154
# Training epoch : 17, [19200 / 50000] (38%), Loss : 2.009347
# Training epoch : 17, [24064 / 50000] (48%), Loss : 2.010202
# Training epoch : 17, [28928 / 50000] (58%), Loss : 2.001716
# Training epoch : 17, [33792 / 50000] (67%), Loss : 1.964444
# Training epoch : 17, [38656 / 50000] (77%), Loss : 1.972751
# Training epoch : 17, [43520 / 50000] (87%), Loss : 1.908381
# Training epoch : 17, [48384 / 50000] (96%), Loss : 1.972413
# Training epoch : 18, [4608 / 50000] (9%), Loss : 1.924797
# Training epoch : 18, [9472 / 50000] (19%), Loss : 1.931777
# Training epoch : 18, [14336 / 50000] (29%), Loss : 1.960614
# Training epoch : 18, [19200 / 50000] (38%), Loss : 1.937537
# Training epoch : 18, [24064 / 50000] (48%), Loss : 1.948135
# Training epoch : 18, [28928 / 50000] (58%), Loss : 1.917970
# Training epoch : 18, [33792 / 50000] (67%), Loss : 1.941204
# Training epoch : 18, [38656 / 50000] (77%), Loss : 1.972084
# Training epoch : 18, [43520 / 50000] (87%), Loss : 1.936890
# Training epoch : 18, [48384 / 50000] (96%), Loss : 1.943723
# Training epoch : 19, [4608 / 50000] (9%), Loss : 1.915825
# Training epoch : 19, [9472 / 50000] (19%), Loss : 1.878479
# Training epoch : 19, [14336 / 50000] (29%), Loss : 1.954360
# Training epoch : 19, [19200 / 50000] (38%), Loss : 1.894745
# Training epoch : 19, [24064 / 50000] (48%), Loss : 1.971990
# Training epoch : 19, [28928 / 50000] (58%), Loss : 1.898944
# Training epoch : 19, [33792 / 50000] (67%), Loss : 1.893085
# Training epoch : 19, [38656 / 50000] (77%), Loss : 1.888801
# Training epoch : 19, [43520 / 50000] (87%), Loss : 1.875993
# Training epoch : 19, [48384 / 50000] (96%), Loss : 1.904885
# Training epoch : 20, [4608 / 50000] (9%), Loss : 1.964770
# Training epoch : 20, [9472 / 50000] (19%), Loss : 1.882829
# Training epoch : 20, [14336 / 50000] (29%), Loss : 1.886579
# Training epoch : 20, [19200 / 50000] (38%), Loss : 1.894422
# Training epoch : 20, [24064 / 50000] (48%), Loss : 1.881654
# Training epoch : 20, [28928 / 50000] (58%), Loss : 1.826891
# Training epoch : 20, [33792 / 50000] (67%), Loss : 1.926660
# Training epoch : 20, [38656 / 50000] (77%), Loss : 1.831512
# Training epoch : 20, [43520 / 50000] (87%), Loss : 1.888704
# Training epoch : 20, [48384 / 50000] (96%), Loss : 1.828427
# Training epoch : 21, [4608 / 50000] (9%), Loss : 1.803191
# Training epoch : 21, [9472 / 50000] (19%), Loss : 1.781011
# Training epoch : 21, [14336 / 50000] (29%), Loss : 1.884432
# Training epoch : 21, [19200 / 50000] (38%), Loss : 1.841444
# Training epoch : 21, [24064 / 50000] (48%), Loss : 1.889075
# Training epoch : 21, [28928 / 50000] (58%), Loss : 1.826699
# Training epoch : 21, [33792 / 50000] (67%), Loss : 1.855422
# Training epoch : 21, [38656 / 50000] (77%), Loss : 1.833826
# Training epoch : 21, [43520 / 50000] (87%), Loss : 1.847795
# Training epoch : 21, [48384 / 50000] (96%), Loss : 1.836888
# Training epoch : 22, [4608 / 50000] (9%), Loss : 1.846470
# Training epoch : 22, [9472 / 50000] (19%), Loss : 1.813055
# Training epoch : 22, [14336 / 50000] (29%), Loss : 1.792160
# Training epoch : 22, [19200 / 50000] (38%), Loss : 1.820225
# Training epoch : 22, [24064 / 50000] (48%), Loss : 1.839459
# Training epoch : 22, [28928 / 50000] (58%), Loss : 1.875918
# Training epoch : 22, [33792 / 50000] (67%), Loss : 1.798708
# Training epoch : 22, [38656 / 50000] (77%), Loss : 1.808031
# Training epoch : 22, [43520 / 50000] (87%), Loss : 1.809763
# Training epoch : 22, [48384 / 50000] (96%), Loss : 1.779750
# Training epoch : 23, [4608 / 50000] (9%), Loss : 1.846538
# Training epoch : 23, [9472 / 50000] (19%), Loss : 1.805471
# Training epoch : 23, [14336 / 50000] (29%), Loss : 1.785169
# Training epoch : 23, [19200 / 50000] (38%), Loss : 1.810071
# Training epoch : 23, [24064 / 50000] (48%), Loss : 1.728542
# Training epoch : 23, [28928 / 50000] (58%), Loss : 1.735296
# Training epoch : 23, [33792 / 50000] (67%), Loss : 1.794277
# Training epoch : 23, [38656 / 50000] (77%), Loss : 1.758928
# Training epoch : 23, [43520 / 50000] (87%), Loss : 1.736179
# Training epoch : 23, [48384 / 50000] (96%), Loss : 1.736818
# Training epoch : 24, [4608 / 50000] (9%), Loss : 1.820533
# Training epoch : 24, [9472 / 50000] (19%), Loss : 1.747101
# Training epoch : 24, [14336 / 50000] (29%), Loss : 1.763492
# Training epoch : 24, [19200 / 50000] (38%), Loss : 1.777994
# Training epoch : 24, [24064 / 50000] (48%), Loss : 1.714212
# Training epoch : 24, [28928 / 50000] (58%), Loss : 1.748299
# Training epoch : 24, [33792 / 50000] (67%), Loss : 1.767011
# Training epoch : 24, [38656 / 50000] (77%), Loss : 1.735639
# Training epoch : 24, [43520 / 50000] (87%), Loss : 1.696021
# Training epoch : 24, [48384 / 50000] (96%), Loss : 1.736657
# Training epoch : 25, [4608 / 50000] (9%), Loss : 1.752692
# Training epoch : 25, [9472 / 50000] (19%), Loss : 1.730358
# Training epoch : 25, [14336 / 50000] (29%), Loss : 1.671966
# Training epoch : 25, [19200 / 50000] (38%), Loss : 1.719451
# Training epoch : 25, [24064 / 50000] (48%), Loss : 1.725037
# Training epoch : 25, [28928 / 50000] (58%), Loss : 1.717039
# Training epoch : 25, [33792 / 50000] (67%), Loss : 1.663950
# Training epoch : 25, [38656 / 50000] (77%), Loss : 1.728802
# Training epoch : 25, [43520 / 50000] (87%), Loss : 1.707119
# Training epoch : 25, [48384 / 50000] (96%), Loss : 1.698194
# Training epoch : 26, [4608 / 50000] (9%), Loss : 1.697994
# Training epoch : 26, [9472 / 50000] (19%), Loss : 1.671891
# Training epoch : 26, [14336 / 50000] (29%), Loss : 1.656286
# Training epoch : 26, [19200 / 50000] (38%), Loss : 1.671182
# Training epoch : 26, [24064 / 50000] (48%), Loss : 1.735657
# Training epoch : 26, [28928 / 50000] (58%), Loss : 1.673776
# Training epoch : 26, [33792 / 50000] (67%), Loss : 1.691255
# Training epoch : 26, [38656 / 50000] (77%), Loss : 1.673432
# Training epoch : 26, [43520 / 50000] (87%), Loss : 1.670850
# Training epoch : 26, [48384 / 50000] (96%), Loss : 1.667084
# Training epoch : 27, [4608 / 50000] (9%), Loss : 1.661374
# Training epoch : 27, [9472 / 50000] (19%), Loss : 1.630223
# Training epoch : 27, [14336 / 50000] (29%), Loss : 1.636609
# Training epoch : 27, [19200 / 50000] (38%), Loss : 1.664832
# Training epoch : 27, [24064 / 50000] (48%), Loss : 1.587397
# Training epoch : 27, [28928 / 50000] (58%), Loss : 1.689632
# Training epoch : 27, [33792 / 50000] (67%), Loss : 1.642014
# Training epoch : 27, [38656 / 50000] (77%), Loss : 1.641794
# Training epoch : 27, [43520 / 50000] (87%), Loss : 1.634855
# Training epoch : 27, [48384 / 50000] (96%), Loss : 1.637400
# Training epoch : 28, [4608 / 50000] (9%), Loss : 1.601551
# Training epoch : 28, [9472 / 50000] (19%), Loss : 1.590715
# Training epoch : 28, [14336 / 50000] (29%), Loss : 1.654550
# Training epoch : 28, [19200 / 50000] (38%), Loss : 1.598798
# Training epoch : 28, [24064 / 50000] (48%), Loss : 1.619545
# Training epoch : 28, [28928 / 50000] (58%), Loss : 1.641943
# Training epoch : 28, [33792 / 50000] (67%), Loss : 1.576271
# Training epoch : 28, [38656 / 50000] (77%), Loss : 1.616434
# Training epoch : 28, [43520 / 50000] (87%), Loss : 1.618893
# Training epoch : 28, [48384 / 50000] (96%), Loss : 1.629339
# Training epoch : 29, [4608 / 50000] (9%), Loss : 1.581746
# Training epoch : 29, [9472 / 50000] (19%), Loss : 1.598191
# Training epoch : 29, [14336 / 50000] (29%), Loss : 1.571248
# Training epoch : 29, [19200 / 50000] (38%), Loss : 1.600218
# Training epoch : 29, [24064 / 50000] (48%), Loss : 1.579617
# Training epoch : 29, [28928 / 50000] (58%), Loss : 1.590487
# Training epoch : 29, [33792 / 50000] (67%), Loss : 1.570512
# Training epoch : 29, [38656 / 50000] (77%), Loss : 1.624581
# Training epoch : 29, [43520 / 50000] (87%), Loss : 1.591052
# Training epoch : 29, [48384 / 50000] (96%), Loss : 1.562119
# Training epoch : 30, [4608 / 50000] (9%), Loss : 1.559495
# Training epoch : 30, [9472 / 50000] (19%), Loss : 1.531473
# Training epoch : 30, [14336 / 50000] (29%), Loss : 1.566712
# Training epoch : 30, [19200 / 50000] (38%), Loss : 1.558411
# Training epoch : 30, [24064 / 50000] (48%), Loss : 1.631234
# Training epoch : 30, [28928 / 50000] (58%), Loss : 1.580226
# Training epoch : 30, [33792 / 50000] (67%), Loss : 1.601687
# Training epoch : 30, [38656 / 50000] (77%), Loss : 1.570718
# Training epoch : 30, [43520 / 50000] (87%), Loss : 1.533447
# Training epoch : 30, [48384 / 50000] (96%), Loss : 1.543564
# Training epoch : 31, [4608 / 50000] (9%), Loss : 1.507690
# Training epoch : 31, [9472 / 50000] (19%), Loss : 1.481920
# Training epoch : 31, [14336 / 50000] (29%), Loss : 1.509490
# Training epoch : 31, [19200 / 50000] (38%), Loss : 1.579376
# Training epoch : 31, [24064 / 50000] (48%), Loss : 1.539824
# Training epoch : 31, [28928 / 50000] (58%), Loss : 1.564392
# Training epoch : 31, [33792 / 50000] (67%), Loss : 1.603255
# Training epoch : 31, [38656 / 50000] (77%), Loss : 1.569457
# Training epoch : 31, [43520 / 50000] (87%), Loss : 1.520981
# Training epoch : 31, [48384 / 50000] (96%), Loss : 1.555382
# Training epoch : 32, [4608 / 50000] (9%), Loss : 1.538834
# Training epoch : 32, [9472 / 50000] (19%), Loss : 1.506277
# Training epoch : 32, [14336 / 50000] (29%), Loss : 1.518661
# Training epoch : 32, [19200 / 50000] (38%), Loss : 1.489449
# Training epoch : 32, [24064 / 50000] (48%), Loss : 1.480661
# Training epoch : 32, [28928 / 50000] (58%), Loss : 1.510558
# Training epoch : 32, [33792 / 50000] (67%), Loss : 1.495888
# Training epoch : 32, [38656 / 50000] (77%), Loss : 1.461220
# Training epoch : 32, [43520 / 50000] (87%), Loss : 1.479467
# Training epoch : 32, [48384 / 50000] (96%), Loss : 1.461490
# Training epoch : 33, [4608 / 50000] (9%), Loss : 1.490394
# Training epoch : 33, [9472 / 50000] (19%), Loss : 1.474629
# Training epoch : 33, [14336 / 50000] (29%), Loss : 1.509086
# Training epoch : 33, [19200 / 50000] (38%), Loss : 1.508339
# Training epoch : 33, [24064 / 50000] (48%), Loss : 1.445942
# Training epoch : 33, [28928 / 50000] (58%), Loss : 1.483899
# Training epoch : 33, [33792 / 50000] (67%), Loss : 1.495369
# Training epoch : 33, [38656 / 50000] (77%), Loss : 1.479010
# Training epoch : 33, [43520 / 50000] (87%), Loss : 1.425164
# Training epoch : 33, [48384 / 50000] (96%), Loss : 1.495075
# Training epoch : 34, [4608 / 50000] (9%), Loss : 1.475668
# Training epoch : 34, [9472 / 50000] (19%), Loss : 1.503524
# Training epoch : 34, [14336 / 50000] (29%), Loss : 1.418339
# Training epoch : 34, [19200 / 50000] (38%), Loss : 1.460221
# Training epoch : 34, [24064 / 50000] (48%), Loss : 1.457099
# Training epoch : 34, [28928 / 50000] (58%), Loss : 1.454010
# Training epoch : 34, [33792 / 50000] (67%), Loss : 1.408932
# Training epoch : 34, [38656 / 50000] (77%), Loss : 1.454441
# Training epoch : 34, [43520 / 50000] (87%), Loss : 1.481557
# Training epoch : 34, [48384 / 50000] (96%), Loss : 1.467406
# Training epoch : 35, [4608 / 50000] (9%), Loss : 1.432628
# Training epoch : 35, [9472 / 50000] (19%), Loss : 1.414374
# Training epoch : 35, [14336 / 50000] (29%), Loss : 1.460086
# Training epoch : 35, [19200 / 50000] (38%), Loss : 1.449403
# Training epoch : 35, [24064 / 50000] (48%), Loss : 1.430537
# Training epoch : 35, [28928 / 50000] (58%), Loss : 1.436982
# Training epoch : 35, [33792 / 50000] (67%), Loss : 1.421103
# Training epoch : 35, [38656 / 50000] (77%), Loss : 1.441939
# Training epoch : 35, [43520 / 50000] (87%), Loss : 1.451549
# Training epoch : 35, [48384 / 50000] (96%), Loss : 1.418645
# Training epoch : 36, [4608 / 50000] (9%), Loss : 1.410375
# Training epoch : 36, [9472 / 50000] (19%), Loss : 1.433639
# Training epoch : 36, [14336 / 50000] (29%), Loss : 1.401192
# Training epoch : 36, [19200 / 50000] (38%), Loss : 1.351471
# Training epoch : 36, [24064 / 50000] (48%), Loss : 1.426490
# Training epoch : 36, [28928 / 50000] (58%), Loss : 1.420965
# Training epoch : 36, [33792 / 50000] (67%), Loss : 1.385844
# Training epoch : 36, [38656 / 50000] (77%), Loss : 1.352543
# Training epoch : 36, [43520 / 50000] (87%), Loss : 1.373625
# Training epoch : 36, [48384 / 50000] (96%), Loss : 1.417814
# Training epoch : 37, [4608 / 50000] (9%), Loss : 1.431230
# Training epoch : 37, [9472 / 50000] (19%), Loss : 1.333437
# Training epoch : 37, [14336 / 50000] (29%), Loss : 1.379405
# Training epoch : 37, [19200 / 50000] (38%), Loss : 1.313760
# Training epoch : 37, [24064 / 50000] (48%), Loss : 1.351358
# Training epoch : 37, [28928 / 50000] (58%), Loss : 1.374713
# Training epoch : 37, [33792 / 50000] (67%), Loss : 1.370145
# Training epoch : 37, [38656 / 50000] (77%), Loss : 1.377693
# Training epoch : 37, [43520 / 50000] (87%), Loss : 1.379524
# Training epoch : 37, [48384 / 50000] (96%), Loss : 1.407837
# Training epoch : 38, [4608 / 50000] (9%), Loss : 1.381860
# Training epoch : 38, [9472 / 50000] (19%), Loss : 1.335578
# Training epoch : 38, [14336 / 50000] (29%), Loss : 1.363249
# Training epoch : 38, [19200 / 50000] (38%), Loss : 1.395746
# Training epoch : 38, [24064 / 50000] (48%), Loss : 1.344278
# Training epoch : 38, [28928 / 50000] (58%), Loss : 1.347206
# Training epoch : 38, [33792 / 50000] (67%), Loss : 1.372035
# Training epoch : 38, [38656 / 50000] (77%), Loss : 1.371345
# Training epoch : 38, [43520 / 50000] (87%), Loss : 1.305557
# Training epoch : 38, [48384 / 50000] (96%), Loss : 1.398216
# Training epoch : 39, [4608 / 50000] (9%), Loss : 1.306715
# Training epoch : 39, [9472 / 50000] (19%), Loss : 1.338560
# Training epoch : 39, [14336 / 50000] (29%), Loss : 1.311151
# Training epoch : 39, [19200 / 50000] (38%), Loss : 1.356869
# Training epoch : 39, [24064 / 50000] (48%), Loss : 1.356294
# Training epoch : 39, [28928 / 50000] (58%), Loss : 1.310739
# Training epoch : 39, [33792 / 50000] (67%), Loss : 1.345777
# Training epoch : 39, [38656 / 50000] (77%), Loss : 1.355602
# Training epoch : 39, [43520 / 50000] (87%), Loss : 1.318002
# Training epoch : 39, [48384 / 50000] (96%), Loss : 1.300090
# Training epoch : 40, [4608 / 50000] (9%), Loss : 1.311353
# Training epoch : 40, [9472 / 50000] (19%), Loss : 1.334937
# Training epoch : 40, [14336 / 50000] (29%), Loss : 1.295622
# Training epoch : 40, [19200 / 50000] (38%), Loss : 1.345587
# Training epoch : 40, [24064 / 50000] (48%), Loss : 1.279647
# Training epoch : 40, [28928 / 50000] (58%), Loss : 1.294363
# Training epoch : 40, [33792 / 50000] (67%), Loss : 1.306067
# Training epoch : 40, [38656 / 50000] (77%), Loss : 1.326383
# Training epoch : 40, [43520 / 50000] (87%), Loss : 1.294777
# Training epoch : 40, [48384 / 50000] (96%), Loss : 1.283942
# Training epoch : 41, [4608 / 50000] (9%), Loss : 1.275714
# Training epoch : 41, [9472 / 50000] (19%), Loss : 1.311511
# Training epoch : 41, [14336 / 50000] (29%), Loss : 1.265782
# Training epoch : 41, [19200 / 50000] (38%), Loss : 1.290419
# Training epoch : 41, [24064 / 50000] (48%), Loss : 1.294254
# Training epoch : 41, [28928 / 50000] (58%), Loss : 1.279907
# Training epoch : 41, [33792 / 50000] (67%), Loss : 1.265474
# Training epoch : 41, [38656 / 50000] (77%), Loss : 1.302906
# Training epoch : 41, [43520 / 50000] (87%), Loss : 1.271610
# Training epoch : 41, [48384 / 50000] (96%), Loss : 1.251629
# Training epoch : 42, [4608 / 50000] (9%), Loss : 1.281078
# Training epoch : 42, [9472 / 50000] (19%), Loss : 1.215403
# Training epoch : 42, [14336 / 50000] (29%), Loss : 1.228295
# Training epoch : 42, [19200 / 50000] (38%), Loss : 1.280242
# Training epoch : 42, [24064 / 50000] (48%), Loss : 1.257381
# Training epoch : 42, [28928 / 50000] (58%), Loss : 1.248411
# Training epoch : 42, [33792 / 50000] (67%), Loss : 1.282382
# Training epoch : 42, [38656 / 50000] (77%), Loss : 1.269723
# Training epoch : 42, [43520 / 50000] (87%), Loss : 1.243175
# Training epoch : 42, [48384 / 50000] (96%), Loss : 1.219336
# Training epoch : 43, [4608 / 50000] (9%), Loss : 1.231512
# Training epoch : 43, [9472 / 50000] (19%), Loss : 1.229956
# Training epoch : 43, [14336 / 50000] (29%), Loss : 1.293185
# Training epoch : 43, [19200 / 50000] (38%), Loss : 1.250718
# Training epoch : 43, [24064 / 50000] (48%), Loss : 1.241981
# Training epoch : 43, [28928 / 50000] (58%), Loss : 1.295757
# Training epoch : 43, [33792 / 50000] (67%), Loss : 1.215391
# Training epoch : 43, [38656 / 50000] (77%), Loss : 1.212957
# Training epoch : 43, [43520 / 50000] (87%), Loss : 1.241086
# Training epoch : 43, [48384 / 50000] (96%), Loss : 1.298662
# Training epoch : 44, [4608 / 50000] (9%), Loss : 1.263934
# Training epoch : 44, [9472 / 50000] (19%), Loss : 1.247635
# Training epoch : 44, [14336 / 50000] (29%), Loss : 1.207556
# Training epoch : 44, [19200 / 50000] (38%), Loss : 1.221528
# Training epoch : 44, [24064 / 50000] (48%), Loss : 1.196793
# Training epoch : 44, [28928 / 50000] (58%), Loss : 1.213355
# Training epoch : 44, [33792 / 50000] (67%), Loss : 1.213171
# Training epoch : 44, [38656 / 50000] (77%), Loss : 1.186393
# Training epoch : 44, [43520 / 50000] (87%), Loss : 1.191490
# Training epoch : 44, [48384 / 50000] (96%), Loss : 1.162297
# Training epoch : 45, [4608 / 50000] (9%), Loss : 1.165744
# Training epoch : 45, [9472 / 50000] (19%), Loss : 1.214241
# Training epoch : 45, [14336 / 50000] (29%), Loss : 1.177083
# Training epoch : 45, [19200 / 50000] (38%), Loss : 1.189631
# Training epoch : 45, [24064 / 50000] (48%), Loss : 1.225760
# Training epoch : 45, [28928 / 50000] (58%), Loss : 1.233245
# Training epoch : 45, [33792 / 50000] (67%), Loss : 1.191429
# Training epoch : 45, [38656 / 50000] (77%), Loss : 1.205325
# Training epoch : 45, [43520 / 50000] (87%), Loss : 1.160229
# Training epoch : 45, [48384 / 50000] (96%), Loss : 1.183899
# Training epoch : 46, [4608 / 50000] (9%), Loss : 1.176726
# Training epoch : 46, [9472 / 50000] (19%), Loss : 1.201399
# Training epoch : 46, [14336 / 50000] (29%), Loss : 1.162854
# Training epoch : 46, [19200 / 50000] (38%), Loss : 1.165772
# Training epoch : 46, [24064 / 50000] (48%), Loss : 1.158400
# Training epoch : 46, [28928 / 50000] (58%), Loss : 1.175475
# Training epoch : 46, [33792 / 50000] (67%), Loss : 1.171899
# Training epoch : 46, [38656 / 50000] (77%), Loss : 1.159025
# Training epoch : 46, [43520 / 50000] (87%), Loss : 1.143967
# Training epoch : 46, [48384 / 50000] (96%), Loss : 1.167941
# Training epoch : 47, [4608 / 50000] (9%), Loss : 1.180653
# Training epoch : 47, [9472 / 50000] (19%), Loss : 1.164940
# Training epoch : 47, [14336 / 50000] (29%), Loss : 1.124968
# Training epoch : 47, [19200 / 50000] (38%), Loss : 1.137391
# Training epoch : 47, [24064 / 50000] (48%), Loss : 1.149675
# Training epoch : 47, [28928 / 50000] (58%), Loss : 1.171783
# Training epoch : 47, [33792 / 50000] (67%), Loss : 1.154782
# Training epoch : 47, [38656 / 50000] (77%), Loss : 1.111438
# Training epoch : 47, [43520 / 50000] (87%), Loss : 1.153899
# Training epoch : 47, [48384 / 50000] (96%), Loss : 1.179682
# Training epoch : 48, [4608 / 50000] (9%), Loss : 1.138535
# Training epoch : 48, [9472 / 50000] (19%), Loss : 1.154521
# Training epoch : 48, [14336 / 50000] (29%), Loss : 1.153671
# Training epoch : 48, [19200 / 50000] (38%), Loss : 1.140584
# Training epoch : 48, [24064 / 50000] (48%), Loss : 1.127963
# Training epoch : 48, [28928 / 50000] (58%), Loss : 1.141362
# Training epoch : 48, [33792 / 50000] (67%), Loss : 1.119957
# Training epoch : 48, [38656 / 50000] (77%), Loss : 1.137565
# Training epoch : 48, [43520 / 50000] (87%), Loss : 1.138759
# Training epoch : 48, [48384 / 50000] (96%), Loss : 1.148981
# Training epoch : 49, [4608 / 50000] (9%), Loss : 1.124331
# Training epoch : 49, [9472 / 50000] (19%), Loss : 1.092905
# Training epoch : 49, [14336 / 50000] (29%), Loss : 1.117478
# Training epoch : 49, [19200 / 50000] (38%), Loss : 1.117243
# Training epoch : 49, [24064 / 50000] (48%), Loss : 1.104705
# Training epoch : 49, [28928 / 50000] (58%), Loss : 1.133831
# Training epoch : 49, [33792 / 50000] (67%), Loss : 1.112126
# Training epoch : 49, [38656 / 50000] (77%), Loss : 1.130497
# Training epoch : 49, [43520 / 50000] (87%), Loss : 1.108053
# Training epoch : 49, [48384 / 50000] (96%), Loss : 1.112333
# Training epoch : 50, [4608 / 50000] (9%), Loss : 1.104019
# Training epoch : 50, [9472 / 50000] (19%), Loss : 1.042403
# Training epoch : 50, [14336 / 50000] (29%), Loss : 1.082341
# Training epoch : 50, [19200 / 50000] (38%), Loss : 1.064228
# Training epoch : 50, [24064 / 50000] (48%), Loss : 1.083878
# Training epoch : 50, [28928 / 50000] (58%), Loss : 1.081703
# Training epoch : 50, [33792 / 50000] (67%), Loss : 1.123656
# Training epoch : 50, [38656 / 50000] (77%), Loss : 1.100163
# Training epoch : 50, [43520 / 50000] (87%), Loss : 1.177640
# Training epoch : 50, [48384 / 50000] (96%), Loss : 1.062864
# Training epoch : 55, [38656 / 50000] (77%), Loss : 0.977543
# Training epoch : 55, [43520 / 50000] (87%), Loss : 0.994221
# Training epoch : 55, [48384 / 50000] (96%), Loss : 0.977151
# Training epoch : 56, [4608 / 50000] (9%), Loss : 0.932118
# Training epoch : 56, [9472 / 50000] (19%), Loss : 0.949089
# Training epoch : 56, [14336 / 50000] (29%), Loss : 0.985810
# Training epoch : 56, [19200 / 50000] (38%), Loss : 0.959778
# Training epoch : 56, [24064 / 50000] (48%), Loss : 0.965006
# Training epoch : 56, [28928 / 50000] (58%), Loss : 0.987471
# Training epoch : 56, [33792 / 50000] (67%), Loss : 0.981665
# Training epoch : 56, [38656 / 50000] (77%), Loss : 0.972189
# Training epoch : 56, [43520 / 50000] (87%), Loss : 0.992276
# Training epoch : 56, [48384 / 50000] (96%), Loss : 0.995193
# Training epoch : 57, [4608 / 50000] (9%), Loss : 0.963485
# Training epoch : 57, [9472 / 50000] (19%), Loss : 0.912822
# Training epoch : 57, [14336 / 50000] (29%), Loss : 0.969746
# Training epoch : 57, [19200 / 50000] (38%), Loss : 0.972526
# Training epoch : 57, [24064 / 50000] (48%), Loss : 0.961646
# Training epoch : 57, [28928 / 50000] (58%), Loss : 0.984035
# Training epoch : 57, [33792 / 50000] (67%), Loss : 0.931270
# Training epoch : 57, [38656 / 50000] (77%), Loss : 0.977553
# Training epoch : 57, [43520 / 50000] (87%), Loss : 0.940337
# Training epoch : 57, [48384 / 50000] (96%), Loss : 0.938842
# Training epoch : 58, [4608 / 50000] (9%), Loss : 0.930117
# Training epoch : 58, [9472 / 50000] (19%), Loss : 0.926900
# Training epoch : 58, [14336 / 50000] (29%), Loss : 0.903932
# Training epoch : 58, [19200 / 50000] (38%), Loss : 0.935819
# Training epoch : 58, [24064 / 50000] (48%), Loss : 0.953371
# Training epoch : 58, [28928 / 50000] (58%), Loss : 0.982088
# Training epoch : 58, [33792 / 50000] (67%), Loss : 0.913534
# Training epoch : 58, [38656 / 50000] (77%), Loss : 0.961013
# Training epoch : 58, [43520 / 50000] (87%), Loss : 0.970376
# Training epoch : 58, [48384 / 50000] (96%), Loss : 0.949006
# Training epoch : 59, [4608 / 50000] (9%), Loss : 0.912424
# Training epoch : 59, [9472 / 50000] (19%), Loss : 0.910178
# Training epoch : 59, [14336 / 50000] (29%), Loss : 0.940058
# Training epoch : 59, [19200 / 50000] (38%), Loss : 0.945162
# Training epoch : 59, [24064 / 50000] (48%), Loss : 0.925061
# Training epoch : 59, [28928 / 50000] (58%), Loss : 0.914179
# Training epoch : 59, [33792 / 50000] (67%), Loss : 0.876653
# Training epoch : 59, [38656 / 50000] (77%), Loss : 0.904232
# Training epoch : 59, [43520 / 50000] (87%), Loss : 0.940346
# Training epoch : 59, [48384 / 50000] (96%), Loss : 0.967852
# Training epoch : 60, [4608 / 50000] (9%), Loss : 0.884089
# Training epoch : 60, [9472 / 50000] (19%), Loss : 0.897573
# Training epoch : 60, [14336 / 50000] (29%), Loss : 0.916613
# Training epoch : 60, [19200 / 50000] (38%), Loss : 0.911480
# Training epoch : 74, [33792 / 50000] (67%), Loss : 0.670690
# Training epoch : 74, [38656 / 50000] (77%), Loss : 0.715043
# Training epoch : 74, [43520 / 50000] (87%), Loss : 0.707495
# Training epoch : 74, [48384 / 50000] (96%), Loss : 0.693378
# Training epoch : 75, [4608 / 50000] (9%), Loss : 0.649043
# Training epoch : 75, [9472 / 50000] (19%), Loss : 0.643499
# Training epoch : 75, [14336 / 50000] (29%), Loss : 0.639614
# Training epoch : 75, [19200 / 50000] (38%), Loss : 0.670065
# Training epoch : 75, [24064 / 50000] (48%), Loss : 0.692430
# Training epoch : 75, [28928 / 50000] (58%), Loss : 0.670123
# Training epoch : 75, [33792 / 50000] (67%), Loss : 0.662719
# Training epoch : 75, [38656 / 50000] (77%), Loss : 0.655641
# Training epoch : 75, [43520 / 50000] (87%), Loss : 0.664076
# Training epoch : 75, [48384 / 50000] (96%), Loss : 0.671863
# Training epoch : 76, [4608 / 50000] (9%), Loss : 0.609194
# Training epoch : 76, [9472 / 50000] (19%), Loss : 0.653429
# Training epoch : 76, [14336 / 50000] (29%), Loss : 0.649223
# Training epoch : 76, [19200 / 50000] (38%), Loss : 0.687674
# Training epoch : 76, [24064 / 50000] (48%), Loss : 0.647390
# Training epoch : 76, [28928 / 50000] (58%), Loss : 0.682980
# Training epoch : 76, [33792 / 50000] (67%), Loss : 0.660923
# Training epoch : 76, [38656 / 50000] (77%), Loss : 0.671915
# Training epoch : 76, [43520 / 50000] (87%), Loss : 0.644167
# Training epoch : 76, [48384 / 50000] (96%), Loss : 0.635574
# Training epoch : 77, [4608 / 50000] (9%), Loss : 0.638527
# Training epoch : 77, [9472 / 50000] (19%), Loss : 0.634424
# Training epoch : 77, [14336 / 50000] (29%), Loss : 0.623433
# Training epoch : 77, [19200 / 50000] (38%), Loss : 0.600349
# Training epoch : 77, [24064 / 50000] (48%), Loss : 0.629868
# Training epoch : 77, [28928 / 50000] (58%), Loss : 0.628373
# Training epoch : 77, [33792 / 50000] (67%), Loss : 0.639164
# Training epoch : 77, [38656 / 50000] (77%), Loss : 0.701074
# Training epoch : 77, [43520 / 50000] (87%), Loss : 0.621223
# Training epoch : 77, [48384 / 50000] (96%), Loss : 0.594972
# Training epoch : 78, [4608 / 50000] (9%), Loss : 0.604725
# Training epoch : 78, [9472 / 50000] (19%), Loss : 0.638483
# Training epoch : 78, [14336 / 50000] (29%), Loss : 0.641679
# Training epoch : 78, [19200 / 50000] (38%), Loss : 0.603886
# Training epoch : 78, [24064 / 50000] (48%), Loss : 0.603391
# Training epoch : 78, [28928 / 50000] (58%), Loss : 0.635284
# Training epoch : 78, [33792 / 50000] (67%), Loss : 0.608862
# Training epoch : 78, [38656 / 50000] (77%), Loss : 0.634298
# Training epoch : 78, [43520 / 50000] (87%), Loss : 0.628834
# Training epoch : 78, [48384 / 50000] (96%), Loss : 0.613452
# Training epoch : 79, [4608 / 50000] (9%), Loss : 0.590168
# Training epoch : 79, [9472 / 50000] (19%), Loss : 0.643221
# Training epoch : 79, [14336 / 50000] (29%), Loss : 0.601529
# Training epoch : 79, [19200 / 50000] (38%), Loss : 0.612541
# Training epoch : 79, [24064 / 50000] (48%), Loss : 0.615980
# Training epoch : 79, [28928 / 50000] (58%), Loss : 0.619294
# Training epoch : 79, [33792 / 50000] (67%), Loss : 0.598693
# Training epoch : 79, [38656 / 50000] (77%), Loss : 0.605941
# Training epoch : 79, [43520 / 50000] (87%), Loss : 0.629860
# Training epoch : 79, [48384 / 50000] (96%), Loss : 0.591937
# Training epoch : 80, [4608 / 50000] (9%), Loss : 0.563632
# Training epoch : 80, [9472 / 50000] (19%), Loss : 0.559545
# Training epoch : 80, [14336 / 50000] (29%), Loss : 0.558794
# Training epoch : 80, [19200 / 50000] (38%), Loss : 0.559862
# Training epoch : 80, [24064 / 50000] (48%), Loss : 0.617919
# Training epoch : 80, [28928 / 50000] (58%), Loss : 0.601766
# Training epoch : 80, [33792 / 50000] (67%), Loss : 0.609085
# Training epoch : 80, [38656 / 50000] (77%), Loss : 0.595446
# Training epoch : 80, [43520 / 50000] (87%), Loss : 0.607083
# Training epoch : 80, [48384 / 50000] (96%), Loss : 0.622288
# Training epoch : 81, [4608 / 50000] (9%), Loss : 0.593270
# Training epoch : 81, [9472 / 50000] (19%), Loss : 0.601101
# Training epoch : 81, [14336 / 50000] (29%), Loss : 0.576996
# Training epoch : 81, [19200 / 50000] (38%), Loss : 0.614003
# Training epoch : 81, [24064 / 50000] (48%), Loss : 0.575619
# Training epoch : 81, [28928 / 50000] (58%), Loss : 0.600245
# Training epoch : 81, [33792 / 50000] (67%), Loss : 0.613782
# Training epoch : 81, [38656 / 50000] (77%), Loss : 0.593051
# Training epoch : 81, [43520 / 50000] (87%), Loss : 0.592158
# Training epoch : 81, [48384 / 50000] (96%), Loss : 0.610157
# Training epoch : 82, [4608 / 50000] (9%), Loss : 0.583699
# Training epoch : 82, [9472 / 50000] (19%), Loss : 0.596182
# Training epoch : 82, [14336 / 50000] (29%), Loss : 0.560658
# Training epoch : 82, [19200 / 50000] (38%), Loss : 0.555356
# Training epoch : 82, [24064 / 50000] (48%), Loss : 0.539876
# Training epoch : 82, [28928 / 50000] (58%), Loss : 0.587469
# Training epoch : 82, [33792 / 50000] (67%), Loss : 0.565686
# Training epoch : 82, [38656 / 50000] (77%), Loss : 0.608268
# Training epoch : 82, [43520 / 50000] (87%), Loss : 0.564594
# Training epoch : 82, [48384 / 50000] (96%), Loss : 0.587276
# Training epoch : 83, [4608 / 50000] (9%), Loss : 0.530543
# Training epoch : 83, [9472 / 50000] (19%), Loss : 0.543734
# Training epoch : 83, [14336 / 50000] (29%), Loss : 0.554590
# Training epoch : 83, [19200 / 50000] (38%), Loss : 0.536462
# Training epoch : 83, [24064 / 50000] (48%), Loss : 0.552258
# Training epoch : 83, [28928 / 50000] (58%), Loss : 0.546797
# Training epoch : 83, [33792 / 50000] (67%), Loss : 0.570666
# Training epoch : 83, [38656 / 50000] (77%), Loss : 0.626232
# Training epoch : 83, [43520 / 50000] (87%), Loss : 0.603845
# Training epoch : 83, [48384 / 50000] (96%), Loss : 0.591905
# Training epoch : 84, [4608 / 50000] (9%), Loss : 0.548447
# Training epoch : 84, [9472 / 50000] (19%), Loss : 0.551913
# Training epoch : 84, [14336 / 50000] (29%), Loss : 0.523110
# Training epoch : 84, [19200 / 50000] (38%), Loss : 0.577427
# Training epoch : 84, [24064 / 50000] (48%), Loss : 0.549584
# Training epoch : 84, [28928 / 50000] (58%), Loss : 0.552260
# Training epoch : 84, [33792 / 50000] (67%), Loss : 0.564913
# Training epoch : 84, [38656 / 50000] (77%), Loss : 0.560972
# Training epoch : 84, [43520 / 50000] (87%), Loss : 0.599159
# Training epoch : 84, [48384 / 50000] (96%), Loss : 0.579823
# Training epoch : 85, [4608 / 50000] (9%), Loss : 0.553683
# Training epoch : 85, [9472 / 50000] (19%), Loss : 0.535446
# Training epoch : 85, [14336 / 50000] (29%), Loss : 0.532066
# Training epoch : 85, [19200 / 50000] (38%), Loss : 0.584096
# Training epoch : 85, [24064 / 50000] (48%), Loss : 0.563076
# Training epoch : 85, [28928 / 50000] (58%), Loss : 0.559631
# Training epoch : 85, [33792 / 50000] (67%), Loss : 0.551974
# Training epoch : 85, [38656 / 50000] (77%), Loss : 0.585043
# Training epoch : 85, [43520 / 50000] (87%), Loss : 0.539857
# Training epoch : 85, [48384 / 50000] (96%), Loss : 0.553072
# Training epoch : 86, [4608 / 50000] (9%), Loss : 0.507914
# Training epoch : 86, [9472 / 50000] (19%), Loss : 0.497749
# Training epoch : 86, [14336 / 50000] (29%), Loss : 0.539792
# Training epoch : 86, [19200 / 50000] (38%), Loss : 0.540644
# Training epoch : 86, [24064 / 50000] (48%), Loss : 0.539908
# Training epoch : 86, [28928 / 50000] (58%), Loss : 0.540554
# Training epoch : 86, [33792 / 50000] (67%), Loss : 0.521406
# Training epoch : 86, [38656 / 50000] (77%), Loss : 0.560297
# Training epoch : 86, [43520 / 50000] (87%), Loss : 0.561649
# Training epoch : 86, [48384 / 50000] (96%), Loss : 0.554062
# Training epoch : 87, [4608 / 50000] (9%), Loss : 0.519028
# Training epoch : 87, [9472 / 50000] (19%), Loss : 0.521677
# Training epoch : 87, [14336 / 50000] (29%), Loss : 0.516200
# Training epoch : 87, [19200 / 50000] (38%), Loss : 0.529701
# Training epoch : 87, [24064 / 50000] (48%), Loss : 0.511030
# Training epoch : 87, [28928 / 50000] (58%), Loss : 0.554868
# Training epoch : 87, [33792 / 50000] (67%), Loss : 0.539034
# Training epoch : 87, [38656 / 50000] (77%), Loss : 0.565269
# Training epoch : 87, [43520 / 50000] (87%), Loss : 0.546077
# Training epoch : 87, [48384 / 50000] (96%), Loss : 0.550990
# Training epoch : 88, [4608 / 50000] (9%), Loss : 0.556909
# Training epoch : 88, [9472 / 50000] (19%), Loss : 0.518658
# Training epoch : 88, [14336 / 50000] (29%), Loss : 0.494758
# Training epoch : 88, [19200 / 50000] (38%), Loss : 0.492795
# Training epoch : 88, [24064 / 50000] (48%), Loss : 0.523041
# Training epoch : 88, [28928 / 50000] (58%), Loss : 0.513863
# Training epoch : 88, [33792 / 50000] (67%), Loss : 0.528783
# Training epoch : 88, [38656 / 50000] (77%), Loss : 0.505683
# Training epoch : 93, [28928 / 50000] (58%), Loss : 0.499142
# Training epoch : 93, [33792 / 50000] (67%), Loss : 0.500747
# Training epoch : 93, [38656 / 50000] (77%), Loss : 0.498201
# Training epoch : 93, [43520 / 50000] (87%), Loss : 0.504139
# Training epoch : 93, [48384 / 50000] (96%), Loss : 0.500704
# Training epoch : 94, [4608 / 50000] (9%), Loss : 0.466760
# Training epoch : 94, [9472 / 50000] (19%), Loss : 0.465389
# Training epoch : 94, [14336 / 50000] (29%), Loss : 0.460810
# Training epoch : 94, [19200 / 50000] (38%), Loss : 0.473373
# Training epoch : 94, [24064 / 50000] (48%), Loss : 0.476390
# Training epoch : 94, [28928 / 50000] (58%), Loss : 0.525993
# Training epoch : 94, [33792 / 50000] (67%), Loss : 0.527353
# Training epoch : 94, [38656 / 50000] (77%), Loss : 0.493179
# Training epoch : 94, [43520 / 50000] (87%), Loss : 0.489248
# Training epoch : 94, [48384 / 50000] (96%), Loss : 0.512545
# Training epoch : 95, [4608 / 50000] (9%), Loss : 0.488905
# Training epoch : 95, [9472 / 50000] (19%), Loss : 0.479833
# Training epoch : 95, [14336 / 50000] (29%), Loss : 0.462510
# Training epoch : 95, [19200 / 50000] (38%), Loss : 0.510896
# Training epoch : 95, [24064 / 50000] (48%), Loss : 0.508103
# Training epoch : 95, [28928 / 50000] (58%), Loss : 0.481051
# Training epoch : 95, [33792 / 50000] (67%), Loss : 0.474025
# Training epoch : 95, [38656 / 50000] (77%), Loss : 0.479829
# Training epoch : 95, [43520 / 50000] (87%), Loss : 0.464266
# Training epoch : 95, [48384 / 50000] (96%), Loss : 0.490395
# Training epoch : 96, [4608 / 50000] (9%), Loss : 0.463000
# Training epoch : 96, [9472 / 50000] (19%), Loss : 0.430369
# Training epoch : 96, [14336 / 50000] (29%), Loss : 0.428693
# Training epoch : 96, [19200 / 50000] (38%), Loss : 0.446402
# Training epoch : 96, [24064 / 50000] (48%), Loss : 0.470994
# Training epoch : 96, [28928 / 50000] (58%), Loss : 0.478674
# Training epoch : 96, [33792 / 50000] (67%), Loss : 0.468699
# Training epoch : 96, [38656 / 50000] (77%), Loss : 0.454542
# Training epoch : 96, [43520 / 50000] (87%), Loss : 0.453256
# Training epoch : 96, [48384 / 50000] (96%), Loss : 0.460776
# Training epoch : 97, [4608 / 50000] (9%), Loss : 0.458114
# Training epoch : 97, [9472 / 50000] (19%), Loss : 0.461155
# Training epoch : 97, [14336 / 50000] (29%), Loss : 0.439571
# Training epoch : 97, [19200 / 50000] (38%), Loss : 0.463480
# Training epoch : 97, [24064 / 50000] (48%), Loss : 0.435512
# Training epoch : 97, [28928 / 50000] (58%), Loss : 0.458749
# Training epoch : 97, [33792 / 50000] (67%), Loss : 0.465227
# Training epoch : 97, [38656 / 50000] (77%), Loss : 0.465273
# Training epoch : 97, [43520 / 50000] (87%), Loss : 0.460268
# Training epoch : 97, [48384 / 50000] (96%), Loss : 0.473216
# Training epoch : 98, [4608 / 50000] (9%), Loss : 0.470951
# Training epoch : 98, [9472 / 50000] (19%), Loss : 0.476484
# Training epoch : 98, [14336 / 50000] (29%), Loss : 0.473590
# Training epoch : 98, [19200 / 50000] (38%), Loss : 0.462708
# Training epoch : 98, [24064 / 50000] (48%), Loss : 0.457722
# Training epoch : 98, [28928 / 50000] (58%), Loss : 0.472262
# Training epoch : 98, [33792 / 50000] (67%), Loss : 0.454368
# Training epoch : 98, [38656 / 50000] (77%), Loss : 0.449300
# Training epoch : 98, [43520 / 50000] (87%), Loss : 0.474191
# Training epoch : 98, [48384 / 50000] (96%), Loss : 0.453916
# Training epoch : 99, [4608 / 50000] (9%), Loss : 0.453547
# Training epoch : 99, [9472 / 50000] (19%), Loss : 0.433476
# Training epoch : 99, [14336 / 50000] (29%), Loss : 0.437812
# Training epoch : 99, [19200 / 50000] (38%), Loss : 0.449089
# Training epoch : 99, [24064 / 50000] (48%), Loss : 0.466961
# Training epoch : 99, [28928 / 50000] (58%), Loss : 0.459050
# Training epoch : 99, [33792 / 50000] (67%), Loss : 0.454983
# Training epoch : 99, [38656 / 50000] (77%), Loss : 0.451163
# Training epoch : 99, [43520 / 50000] (87%), Loss : 0.482332
# Training epoch : 99, [48384 / 50000] (96%), Loss : 0.504107
# Training epoch : 100, [4608 / 50000] (9%), Loss : 0.432283
# Training epoch : 100, [9472 / 50000] (19%), Loss : 0.408431
# Training epoch : 100, [14336 / 50000] (29%), Loss : 0.440976
# Training epoch : 100, [19200 / 50000] (38%), Loss : 0.445075
# Training epoch : 100, [24064 / 50000] (48%), Loss : 0.442614
# Training epoch : 100, [28928 / 50000] (58%), Loss : 0.434167
# Training epoch : 100, [33792 / 50000] (67%), Loss : 0.448892
# Training epoch : 100, [38656 / 50000] (77%), Loss : 0.432238
# Training epoch : 100, [43520 / 50000] (87%), Loss : 0.452753
# Training epoch : 100, [48384 / 50000] (96%), Loss : 0.446267
# 학습종료!

# %% [markdown]
# # 학습 결과 loss 시각화

# %%
plt.plot(loss_arr)
plt.show()

# %% [markdown]
# # 테스트

# %%
# test
model.eval() # drop out 같은 학습에만 필요하고 test에는 불필요한 층을 비활성화

# 클래스 개수대로 정답 개수, 총 개수 구하기
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))


with torch.no_grad(): # gradient 연산을 멈춘 상태로 계산, 메모리 절약 및 연산속도 증가
    for data in test_dataloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)

        # 결과 예측
        outputs = model(images) # 모델 실행

        # 이미지가 가질 수 있는 라벨 중 가장 높은 확률과 인덱스(라벨)를 출력
        _, predicted = torch.max(outputs.data, dim=1)

        # 라벨과 정답이 일치하는지 확인
        c = (predicted == labels).squeeze()

        # 한번에 배치 사이즈만큼 예측하기 때문에 batch_size 개수만큼 예측 결과가 나옴
        for i in range(len(data)):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

# %%
# test 결과 확인
total_correct = 0
total = 0

for i in range(10):
    total_correct += class_correct[i]
    total += class_total[i]
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))

print(f'Total accuracy : {100 * total_correct/total:0.2f}%')
# Out:
# Accuracy of airplane : 83 %
# Accuracy of automobile : 80 %
# Accuracy of  bird : 75 %
# Accuracy of   cat : 37 %
# Accuracy of  deer : 50 %
# Accuracy of   dog : 55 %
# Accuracy of  frog : 80 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 90 %
# Accuracy of truck : 85 %
# Total accuracy : 68.75%
